# %%
import pandas as pd

# %% [markdown]
# # Read dataset

# %%
dataset=pd.read_csv("D:\Datasets\weatherAUS.csv")

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %% [markdown]
# # Information of dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
# Date             145460 non-null object
# Location         145460 non-null object
# MinTemp          143975 non-null float64
# MaxTemp          144199 non-null float64
# Rainfall         142199 non-null float64
# Evaporation      82670 non-null float64
# Sunshine         75625 non-null float64
# WindGustDir      135134 non-null object
# WindGustSpeed    135197 non-null float64
# WindDir9am       134894 non-null object
# WindDir3pm       141232 non-null object
# WindSpeed9am     143693 non-null float64
# WindSpeed3pm     142398 non-null float64
# Humidity9am      142806 non-null float64
# Humidity3pm      140953 non-null float64
# Pressure9am      130395 non-null float64
# Pressure3pm      130432 non-null float64
# Cloud9am         89572 non-null float64
# Cloud3pm         86102 non-null float64
# Temp9am          143693 non-null float64
# ...

# %% [markdown]
# # Descibe dataset

# %%
dataset.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %% [markdown]
# # isnull().any()

# %%
dataset.isnull().any()
# Out:
# Date             False
# Location         False
# MinTemp           True
# MaxTemp           True
# Rainfall          True
# Evaporation       True
# Sunshine          True
# WindGustDir       True
# WindGustSpeed     True
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am      True
# WindSpeed3pm      True
# Humidity9am       True
# Humidity3pm       True
# Pressure9am       True
# Pressure3pm       True
# Cloud9am          True
# Cloud3pm          True
# Temp9am           True
# Temp3pm           True
# RainToday         True
# RainTomorrow      True
# dtype: bool

# %% [markdown]
# # isnull().sum()

# %%
dataset.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# # unique()

# %%
dataset["MinTemp"].unique()
# Out:
# array([ 13.4,   7.4,  12.9,   9.2,  17.5,  14.6,  14.3,   7.7,   9.7,
#         13.1,  15.9,  12.6,   8.4,   9.8,  14.1,  13.5,  11.2,  11.5,
#         17.1,  20.5,  15.3,  16.2,  16.9,  20.1,  19.7,  12.5,  12. ,
#         11.3,   9.6,  10.5,  12.3,  13.7,  16.1,  14. ,  17. ,  17.3,
#         17.2,  17.4,  19.8,  14.9,  13.9,  18.6,  19.3,  24.4,  18.8,
#         20.8,  15.7,  18.5,  20.4,  21.8,  22.3,  22. ,  28. ,  21.5,
#         21.7,  23.5,  28.3,  18.4,  12.4,  13.3,  18. ,  18.7,  15.5,
#          8.9,  15. ,  15.4,  16. ,  12.8,  13.2,  13.8,   7.6,   8.3,
#         11. ,  20.9,  16.4,  10. ,   8.8,   9.3,  14.4,  10.8,  10.1,
#          9.1,  10.4,  12.2,  10.7,   7.8,   8.1,   7.5,   8.2,  11.6,
#         13. ,   9.9,   3.5,   6.6,   7. ,   5.7,   6.2,   6. ,  10.6,
#          8.6,   4.5,   5.4,   2.1,   1.8,   7.2,   4.6,   4.2,   5.2,
#          4.1,   3.2,   4.3,   3.7,   3.6,   6.9,  10.3,   3. ,   2.6,
# ...

# %% [markdown]
# # value_counts()

# %%
dataset["MinTemp"].value_counts()
# Out:
#  11.0    899
#  10.2    898
#  9.6     896
#  10.5    884
#  10.8    872
#  9.0     872
#  10.0    871
#  12.0    866
#  8.9     861
#  10.4    860
#  13.0    858
#  9.7     854
#  11.3    853
#  11.8    849
#  11.5    848
#  10.9    846
#  12.7    844
#  8.5     844
#  11.4    837
#  12.4    828
#  11.6    828
#  13.2    824
#  9.3     823
#  12.2    820
#  9.8     820
#  9.4     818
#  10.7    818
#  11.7    817
#  12.5    816
#  10.3    816
#         ...
#  29.1      5
# -6.6       4
#  29.3      4
#  29.2      4
# -6.8       3
#  31.4      3
# -6.2       3
# -8.0       2
# -7.5       2
# -7.6       2
#  29.6      2
# -6.9       2
# -8.2       2
#  30.7      2
#  33.9      1
# -7.1       1
#  29.9      1
#  30.2      1
#  29.8      1
#  29.5      1
# -8.5       1
# -7.8       1
# -7.3       1
#  30.5      1
#  31.9      1
# -7.2       1
#  31.2      1
#  30.3      1
#  31.8      1
#  31.0      1
# Name: MinTemp, Length: 389, dtype: int64

# %% [markdown]
# # count all rows

# %%
dataset.count()
# Out:
# Date             145460
# Location         145460
# MinTemp          143975
# MaxTemp          144199
# Rainfall         142199
# Evaporation       82670
# Sunshine          75625
# WindGustDir      135134
# WindGustSpeed    135197
# WindDir9am       134894
# WindDir3pm       141232
# WindSpeed9am     143693
# WindSpeed3pm     142398
# Humidity9am      142806
# Humidity3pm      140953
# Pressure9am      130395
# Pressure3pm      130432
# Cloud9am          89572
# Cloud3pm          86102
# Temp9am          143693
# Temp3pm          141851
# RainToday        142199
# RainTomorrow     142193
# dtype: int64

# %% [markdown]
# # count particular row

# %%
dataset["RainToday"].count()
# Out:
# 142199

# %% [markdown]
# # iloc

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %%
x=dataset.iloc[2:145457,2:8]

# %%
x
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir
# 2          12.9     25.7       0.0          NaN       NaN         WSW
# 3           9.2     28.0       0.0          NaN       NaN          NE
# 4          17.5     32.3       1.0          NaN       NaN           W
# 5          14.6     29.7       0.2          NaN       NaN         WNW
# 6          14.3     25.0       0.0          NaN       NaN           W
# 7           7.7     26.7       0.0          NaN       NaN           W
# 8           9.7     31.9       0.0          NaN       NaN         NNW
# 9          13.1     30.1       1.4          NaN       NaN           W
# 10         13.4     30.4       0.0          NaN       NaN           N
# 11         15.9     21.7       2.2          NaN       NaN         NNE
# 12         15.9     18.6      15.6          NaN       NaN           W
# 13         12.6     21.0       3.6          NaN       NaN          SW
# ...

# %% [markdown]
# # Negative indexing

# %%
x=dataset.iloc[:-3,:]

# %%
x
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %% [markdown]
# # loc

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %%
z=dataset.loc[(dataset["Location"]=="Uluru")]

# %%
z
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 143882  2013-03-01    Uluru     19.7     30.0       0.8          NaN
# 143883  2013-03-02    Uluru     21.6     33.1       0.0          NaN
# 143884  2013-03-03    Uluru     21.3     36.1       0.0          NaN
# 143885  2013-03-04    Uluru     22.9     37.7       0.0          NaN
# 143886  2013-03-05    Uluru     24.0     39.0       0.0          NaN
# 143887  2013-03-06    Uluru     24.3     39.7       0.0          NaN
# 143888  2013-03-07    Uluru     26.6     38.6       0.0          NaN
# 143889  2013-03-08    Uluru     26.9     39.4       0.0          NaN
# 143890  2013-03-09    Uluru     24.4     40.0       0.0          NaN
# 143891  2013-03-10    Uluru     25.4     39.8       0.0          NaN
# 143892  2013-03-11    Uluru     23.9     39.5       0.0          NaN
# 143893  2013-03-12    Uluru     20.6     40.9       0.0          NaN
# 143894  2013-03-13    Uluru     22.3     37.3       0.0          NaN
# ...

# %% [markdown]
# # Conditions

# %%
a=dataset.loc[(dataset["MaxTemp"]>=32.0)]

# %%
a
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 21      2008-12-22   Albury     17.1     33.0       0.0          NaN
# 24      2008-12-25   Albury     12.6     32.4       0.0          NaN
# 25      2008-12-26   Albury     16.2     33.9       0.0          NaN
# 26      2008-12-27   Albury     16.9     33.0       0.0          NaN
# 27      2008-12-28   Albury     20.1     32.7       0.0          NaN
# 34      2009-01-04   Albury     12.3     34.6       0.0          NaN
# 35      2009-01-05   Albury     12.9     35.8       0.0          NaN
# 36      2009-01-06   Albury     13.7     37.9       0.0          NaN
# 37      2009-01-07   Albury     16.1     38.9       0.0          NaN
# 41      2009-01-11   Albury     16.9     32.0       0.0          NaN
# 42      2009-01-12   Albury     17.3     34.7       0.0          NaN
# 43      2009-01-13   Albury     17.2     37.7       0.0          NaN
# ...

# %%
a=dataset.loc[(dataset["MaxTemp"]>=32.0) & (dataset["Rainfall"]>=1.0)]

# %%
a
# Out:
#               Date       Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 4       2008-12-05         Albury     17.5     32.3       1.0          NaN
# 53      2009-01-23         Albury     18.8     35.2       6.4          NaN
# 428     2010-02-02         Albury     17.8     34.3       8.6          NaN
# 770     2011-01-10         Albury     20.1     32.0      35.0          NaN
# 794     2011-02-03         Albury     21.9     36.0       3.4          NaN
# 1436    2013-01-06         Albury     20.9     42.0      12.6          NaN
# 1763    2013-12-27         Albury     14.0     32.5       1.4          NaN
# 1777    2014-01-10         Albury     14.4     33.6       1.4          NaN
# 2103    2014-12-02         Albury     15.5     33.2      13.2          NaN
# 2182    2015-02-19         Albury     18.0     33.1       6.0          NaN
# 2569    2016-03-12         Albury     20.0     34.0       6.6          NaN
# ...

# %% [markdown]
# # it matches the conditiond and only shows the these columns

# %%
a=dataset.loc[(dataset["MaxTemp"]>=32.0) & (dataset["Rainfall"]>=1.0),["MaxTemp","Rainfall"]]

# %%
a
# Out:
#         MaxTemp  Rainfall
# 4          32.3       1.0
# 53         35.2       6.4
# 428        34.3       8.6
# 770        32.0      35.0
# 794        36.0       3.4
# 1436       42.0      12.6
# 1763       32.5       1.4
# 1777       33.6       1.4
# 2103       33.2      13.2
# 2182       33.1       6.0
# 2569       34.0       6.6
# 2857       35.6       1.6
# 2862       32.1       3.2
# 2863       33.1       4.4
# 2901       33.1       5.2
# 3061       33.7      19.4
# 3370       34.5       2.8
# 3450       32.7       3.6
# 3793       33.7       1.2
# 3850       32.0      13.2
# 4052       32.9       9.0
# 4134       32.8       1.6
# 5112       34.0       5.4
# 5165       32.8      18.6
# 5166       34.9       8.6
# 5518       34.6       5.0
# 5823       35.7       5.4
# 5868       32.4       5.6
# 5882       38.4       2.4
# 5912       36.0      17.0
# ...         ...       ...
# 144894     37.1       4.6
# 144901     32.1       3.8
# 144907     34.6       4.8
# ...

# %% [markdown]
# # It will shows the only these columns

# %%
z=dataset[["WindGustDir","WindGustSpeed","WindDir9am"]]

# %%
z
# Out:
#        WindGustDir  WindGustSpeed WindDir9am
# 0                W           44.0          W
# 1              WNW           44.0        NNW
# 2              WSW           46.0          W
# 3               NE           24.0         SE
# 4                W           41.0        ENE
# 5              WNW           56.0          W
# 6                W           50.0         SW
# 7                W           35.0        SSE
# 8              NNW           80.0         SE
# 9                W           28.0          S
# 10               N           30.0        SSE
# 11             NNE           31.0         NE
# 12               W           61.0        NNW
# 13              SW           44.0          W
# 14             NaN            NaN          S
# 15             WNW           50.0        NaN
# 16             ENE           22.0        SSW
# 17               W           63.0          N
# 18             SSE           43.0        WSW
# 19             SSE           26.0         SE
# ...

# %% [markdown]
# # It will shows the only these rows and columns

# %%
z=dataset.loc[[5,41,55,89,77,2],["WindGustDir","WindGustSpeed","WindDir9am"]]

# %%
z
# Out:
#    WindGustDir  WindGustSpeed WindDir9am
# 5          WNW           56.0          W
# 41           S           31.0        SSE
# 55         WSW           24.0        ESE
# 89         WSW           44.0          E
# 77           E           35.0         SE
# 2          WSW           46.0          W

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# 5       2008-12-06   Albury     14.6     29.7       0.2          NaN
# 6       2008-12-07   Albury     14.3     25.0       0.0          NaN
# 7       2008-12-08   Albury      7.7     26.7       0.0          NaN
# 8       2008-12-09   Albury      9.7     31.9       0.0          NaN
# 9       2008-12-10   Albury     13.1     30.1       1.4          NaN
# 10      2008-12-11   Albury     13.4     30.4       0.0          NaN
# 11      2008-12-12   Albury     15.9     21.7       2.2          NaN
# 12      2008-12-13   Albury     15.9     18.6      15.6          NaN
# ...

# %%
dataset["Location"].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %% [markdown]
# # replace()

# %%
a=dataset["Location"].replace("Albury","Uluru",inplace=True)

# %%
a

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01    Uluru     13.4     22.9       0.6          NaN
# 1       2008-12-02    Uluru      7.4     25.1       0.0          NaN
# 2       2008-12-03    Uluru     12.9     25.7       0.0          NaN
# 3       2008-12-04    Uluru      9.2     28.0       0.0          NaN
# 4       2008-12-05    Uluru     17.5     32.3       1.0          NaN
# 5       2008-12-06    Uluru     14.6     29.7       0.2          NaN
# 6       2008-12-07    Uluru     14.3     25.0       0.0          NaN
# 7       2008-12-08    Uluru      7.7     26.7       0.0          NaN
# 8       2008-12-09    Uluru      9.7     31.9       0.0          NaN
# 9       2008-12-10    Uluru     13.1     30.1       1.4          NaN
# 10      2008-12-11    Uluru     13.4     30.4       0.0          NaN
# 11      2008-12-12    Uluru     15.9     21.7       2.2          NaN
# 12      2008-12-13    Uluru     15.9     18.6      15.6          NaN
# ...

# %%
a=dataset["Location"].replace("Albury","Uluru",inplace=False)

# %%
a
# Out:
# 0         Uluru
# 1         Uluru
# 2         Uluru
# 3         Uluru
# 4         Uluru
# 5         Uluru
# 6         Uluru
# 7         Uluru
# 8         Uluru
# 9         Uluru
# 10        Uluru
# 11        Uluru
# 12        Uluru
# 13        Uluru
# 14        Uluru
# 15        Uluru
# 16        Uluru
# 17        Uluru
# 18        Uluru
# 19        Uluru
# 20        Uluru
# 21        Uluru
# 22        Uluru
# 23        Uluru
# 24        Uluru
# 25        Uluru
# 26        Uluru
# 27        Uluru
# 28        Uluru
# 29        Uluru
#           ...
# 145430    Uluru
# 145431    Uluru
# 145432    Uluru
# 145433    Uluru
# 145434    Uluru
# 145435    Uluru
# 145436    Uluru
# 145437    Uluru
# 145438    Uluru
# 145439    Uluru
# 145440    Uluru
# 145441    Uluru
# 145442    Uluru
# 145443    Uluru
# 145444    Uluru
# 145445    Uluru
# 145446    Uluru
# 145447    Uluru
# 145448    Uluru
# 145449    Uluru
# 145450    Uluru
# 145451    Uluru
# 145452    Uluru
# 145453    Uluru
# ...

# %% [markdown]
# # drop()

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01    Uluru     13.4     22.9       0.6          NaN
# 1       2008-12-02    Uluru      7.4     25.1       0.0          NaN
# 2       2008-12-03    Uluru     12.9     25.7       0.0          NaN
# 3       2008-12-04    Uluru      9.2     28.0       0.0          NaN
# 4       2008-12-05    Uluru     17.5     32.3       1.0          NaN
# 5       2008-12-06    Uluru     14.6     29.7       0.2          NaN
# 6       2008-12-07    Uluru     14.3     25.0       0.0          NaN
# 7       2008-12-08    Uluru      7.7     26.7       0.0          NaN
# 8       2008-12-09    Uluru      9.7     31.9       0.0          NaN
# 9       2008-12-10    Uluru     13.1     30.1       1.4          NaN
# 10      2008-12-11    Uluru     13.4     30.4       0.0          NaN
# 11      2008-12-12    Uluru     15.9     21.7       2.2          NaN
# 12      2008-12-13    Uluru     15.9     18.6      15.6          NaN
# ...

# %%
s=dataset[["Location","MinTemp","MaxTemp","Rainfall"]]

# %%
s
# Out:
#        Location  MinTemp  MaxTemp  Rainfall
# 0         Uluru     13.4     22.9       0.6
# 1         Uluru      7.4     25.1       0.0
# 2         Uluru     12.9     25.7       0.0
# 3         Uluru      9.2     28.0       0.0
# 4         Uluru     17.5     32.3       1.0
# 5         Uluru     14.6     29.7       0.2
# 6         Uluru     14.3     25.0       0.0
# 7         Uluru      7.7     26.7       0.0
# 8         Uluru      9.7     31.9       0.0
# 9         Uluru     13.1     30.1       1.4
# 10        Uluru     13.4     30.4       0.0
# 11        Uluru     15.9     21.7       2.2
# 12        Uluru     15.9     18.6      15.6
# 13        Uluru     12.6     21.0       3.6
# 14        Uluru      8.4     24.6       0.0
# 15        Uluru      9.8     27.7       NaN
# 16        Uluru     14.1     20.9       0.0
# 17        Uluru     13.5     22.9      16.8
# 18        Uluru     11.2     22.5      10.6
# 19        Uluru      9.8     25.6       0.0
# ...

# %%
x=s.drop(columns=["Location"],inplace=False)

# %%
x
# Out:
#         MinTemp  MaxTemp  Rainfall
# 0          13.4     22.9       0.6
# 1           7.4     25.1       0.0
# 2          12.9     25.7       0.0
# 3           9.2     28.0       0.0
# 4          17.5     32.3       1.0
# 5          14.6     29.7       0.2
# 6          14.3     25.0       0.0
# 7           7.7     26.7       0.0
# 8           9.7     31.9       0.0
# 9          13.1     30.1       1.4
# 10         13.4     30.4       0.0
# 11         15.9     21.7       2.2
# 12         15.9     18.6      15.6
# 13         12.6     21.0       3.6
# 14          8.4     24.6       0.0
# 15          9.8     27.7       NaN
# 16         14.1     20.9       0.0
# 17         13.5     22.9      16.8
# 18         11.2     22.5      10.6
# 19          9.8     25.6       0.0
# 20         11.5     29.3       0.0
# 21         17.1     33.0       0.0
# 22         20.5     31.8       0.0
# 23         15.3     30.9       0.0
# 24         12.6     32.4       0.0
# 25         16.2     33.9       0.0
# ...

# %% [markdown]
# # to_csv

# %%
x.to_csv("Final dataset.csv",index=False)

# %%
d=pd.read_csv("Final dataset.csv")

# %%
d
# Out:
#         MinTemp  MaxTemp  Rainfall
# 0          13.4     22.9       0.6
# 1           7.4     25.1       0.0
# 2          12.9     25.7       0.0
# 3           9.2     28.0       0.0
# 4          17.5     32.3       1.0
# 5          14.6     29.7       0.2
# 6          14.3     25.0       0.0
# 7           7.7     26.7       0.0
# 8           9.7     31.9       0.0
# 9          13.1     30.1       1.4
# 10         13.4     30.4       0.0
# 11         15.9     21.7       2.2
# 12         15.9     18.6      15.6
# 13         12.6     21.0       3.6
# 14          8.4     24.6       0.0
# 15          9.8     27.7       NaN
# 16         14.1     20.9       0.0
# 17         13.5     22.9      16.8
# 18         11.2     22.5      10.6
# 19          9.8     25.6       0.0
# 20         11.5     29.3       0.0
# 21         17.1     33.0       0.0
# 22         20.5     31.8       0.0
# 23         15.3     30.9       0.0
# 24         12.6     32.4       0.0
# 25         16.2     33.9       0.0
# ...

# %%
dataset.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# # fillna()

# %%
mt=dataset["MinTemp"].min()
mt
# Out:
# -8.5

# %%
a=dataset["MinTemp"].fillna(mt,inplace=True)
a

# %%
dataset.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp              0
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
dataset.isnull().any()
# Out:
# Date             False
# Location         False
# MinTemp          False
# MaxTemp           True
# Rainfall          True
# Evaporation       True
# Sunshine          True
# WindGustDir       True
# WindGustSpeed     True
# WindDir9am        True
# WindDir3pm        True
# WindSpeed9am      True
# WindSpeed3pm      True
# Humidity9am       True
# Humidity3pm       True
# Pressure9am       True
# Pressure3pm       True
# Cloud9am          True
# Cloud3pm          True
# Temp9am           True
# Temp3pm           True
# RainToday         True
# RainTomorrow      True
# dtype: bool

# %%
dataset["MinTemp"].unique()
# Out:
# array([ 13.4,   7.4,  12.9,   9.2,  17.5,  14.6,  14.3,   7.7,   9.7,
#         13.1,  15.9,  12.6,   8.4,   9.8,  14.1,  13.5,  11.2,  11.5,
#         17.1,  20.5,  15.3,  16.2,  16.9,  20.1,  19.7,  12.5,  12. ,
#         11.3,   9.6,  10.5,  12.3,  13.7,  16.1,  14. ,  17. ,  17.3,
#         17.2,  17.4,  19.8,  14.9,  13.9,  18.6,  19.3,  24.4,  18.8,
#         20.8,  15.7,  18.5,  20.4,  21.8,  22.3,  22. ,  28. ,  21.5,
#         21.7,  23.5,  28.3,  18.4,  12.4,  13.3,  18. ,  18.7,  15.5,
#          8.9,  15. ,  15.4,  16. ,  12.8,  13.2,  13.8,   7.6,   8.3,
#         11. ,  20.9,  16.4,  10. ,   8.8,   9.3,  14.4,  10.8,  10.1,
#          9.1,  10.4,  12.2,  10.7,   7.8,   8.1,   7.5,   8.2,  11.6,
#         13. ,   9.9,   3.5,   6.6,   7. ,   5.7,   6.2,   6. ,  10.6,
#          8.6,   4.5,   5.4,   2.1,   1.8,   7.2,   4.6,   4.2,   5.2,
#          4.1,   3.2,   4.3,   3.7,   3.6,   6.9,  10.3,   3. ,   2.6,
# ...

# %% [markdown]
# # add columns

# %%
s=[]
for x in dataset["MinTemp"]:
    n=x+2
    s.append(n)
print(s)
# Out:
# [15.4, 9.4, 14.9, 11.2, 19.5, 16.6, 16.3, 9.7, 11.7, 15.1, 15.4, 17.9, 17.9, 14.6, 10.4, 11.8, 16.1, 15.5, 13.2, 11.8, 13.5, 19.1, 22.5, 17.3, 14.6, 18.2, 18.9, 22.1, 21.7, 14.5, 14.0, 13.3, 11.6, 12.5, 14.3, 14.9, 15.7, 18.1, 16.0, 14.5, 19.0, 18.9, 19.3, 19.2, 19.4, 21.8, 16.9, 12.5, 13.3, 15.9, 20.6, 21.3, 26.4, 20.8, 22.8, 16.0, 17.7, 20.5, 22.4, 23.8, 24.3, 24.0, 30.0, 26.4, 23.5, 23.7, 23.5, 25.5, 24.3, 30.3, 20.4, 16.9, 15.5, 18.1, 16.6, 14.4, 15.3, 19.2, 14.5, 20.0, 18.2, 20.7, 15.7, 17.5, 16.3, 14.9, 10.9, 17.0, 17.4, 18.0, 14.8, 15.2, 20.0, 15.8, 13.5, 9.6, 10.3, 13.0, 15.8, 17.5, 20.4, 22.9, 19.1, 18.4, 12.0, 10.8, 10.4, 11.3, 13.3, 13.5, 15.8, 16.6, 16.4, 12.8, 17.4, 15.3, 12.1, 11.1, 12.4, 15.4, 14.3, 14.2, 16.3, 20.4, 12.7, 9.8, 10.1, 9.5, 10.2, 10.1, 13.6, 15.0, 15.5, 11.9, 14.2, 12.7, 5.5, 8.6, 9.0, 13.2, 9.4, 7.7, 8.2, 8.0, 12.6, 14.9, 10.6, 6.5, 9.6, 7.4, 4.1, 3.8, 9.2, 6.6, 6.2, 7.2, 6.1, 5.2, 6.3, 5.7, 7.4, 6.3, 5.6, 5.6, 8.9, 12.3, 14.4, 5.0, 4.6, 5.7, 7.1, 6.4, 
# ...

# %%
dataset["Updated"]=s

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01    Uluru     13.4     22.9       0.6          NaN
# 1       2008-12-02    Uluru      7.4     25.1       0.0          NaN
# 2       2008-12-03    Uluru     12.9     25.7       0.0          NaN
# 3       2008-12-04    Uluru      9.2     28.0       0.0          NaN
# 4       2008-12-05    Uluru     17.5     32.3       1.0          NaN
# 5       2008-12-06    Uluru     14.6     29.7       0.2          NaN
# 6       2008-12-07    Uluru     14.3     25.0       0.0          NaN
# 7       2008-12-08    Uluru      7.7     26.7       0.0          NaN
# 8       2008-12-09    Uluru      9.7     31.9       0.0          NaN
# 9       2008-12-10    Uluru     13.1     30.1       1.4          NaN
# 10      2008-12-11    Uluru     13.4     30.4       0.0          NaN
# 11      2008-12-12    Uluru     15.9     21.7       2.2          NaN
# 12      2008-12-13    Uluru     15.9     18.6      15.6          NaN
# ...

# %% [markdown]
# # insert column

# %%
s=[]
for x in dataset["MaxTemp"]:
    n=x+2
    s.append(n)
print(s)
# Out:
# [24.9, 27.1, 27.7, 30.0, 34.3, 31.7, 27.0, 28.7, 33.9, 32.1, 32.4, 23.7, 20.6, 23.0, 26.6, 29.7, 22.9, 24.9, 24.5, 27.6, 31.3, 35.0, 33.8, 32.9, 34.4, 35.9, 35.0, 34.7, 29.2, 26.2, 26.4, 28.5, 25.9, 30.8, 36.6, 37.8, 39.9, 40.9, 30.3, 30.4, 32.8, 34.0, 36.7, 39.7, 45.0, 34.7, 28.7, 30.4, 34.2, 38.6, 41.9, 40.1, 36.0, 37.2, 32.6, 36.3, 40.4, 40.2, 42.7, 43.5, 44.9, 44.7, 45.1, 40.3, 39.7, 38.9, 43.2, 44.2, 46.8, 42.2, 33.2, 29.3, 28.7, 23.6, 31.0, 31.2, 33.3, 33.1, 30.8, 34.0, 36.0, 31.1, 33.7, 35.2, 36.0, 31.6, 33.9, 34.7, 34.6, 36.5, 32.3, 33.9, 33.1, 24.1, 24.0, 26.0, 29.9, 32.2, 33.8, 34.0, 32.5, 27.7, 27.8, 29.0, 21.7, 23.9, 27.3, 30.0, 32.1, 35.5, 35.6, 32.0, 33.6, 33.9, 24.3, 31.8, 29.6, 30.9, 33.2, 32.4, 31.9, 32.6, 34.1, 30.1, 23.4, 23.7, 23.4, 24.5, 26.0, 27.7, 28.7, 26.9, 26.2, 27.4, 27.0, 23.9, 22.0, 23.6, 25.4, 25.9, 24.0, 23.4, 24.7, 24.9, 18.2, 17.8, 14.9, 13.5, 16.5, 14.2, 18.5, 19.0, 21.2, 20.9, 21.1, 20.8, 21.3, 20.4, 21.0, 22.5, 21.5, 19.7, 20.5, 17.1, 18.3, 18.6, 1
# ...

# %%
dataset.insert(4,"MaxTempUp",s)

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  MaxTempUp  Rainfall  \
# 0       2008-12-01    Uluru     13.4     22.9       24.9       0.6
# 1       2008-12-02    Uluru      7.4     25.1       27.1       0.0
# 2       2008-12-03    Uluru     12.9     25.7       27.7       0.0
# 3       2008-12-04    Uluru      9.2     28.0       30.0       0.0
# 4       2008-12-05    Uluru     17.5     32.3       34.3       1.0
# 5       2008-12-06    Uluru     14.6     29.7       31.7       0.2
# 6       2008-12-07    Uluru     14.3     25.0       27.0       0.0
# 7       2008-12-08    Uluru      7.7     26.7       28.7       0.0
# 8       2008-12-09    Uluru      9.7     31.9       33.9       0.0
# 9       2008-12-10    Uluru     13.1     30.1       32.1       1.4
# 10      2008-12-11    Uluru     13.4     30.4       32.4       0.0
# 11      2008-12-12    Uluru     15.9     21.7       23.7       2.2
# 12      2008-12-13    Uluru     15.9     18.6       20.6      15.6
# ...
