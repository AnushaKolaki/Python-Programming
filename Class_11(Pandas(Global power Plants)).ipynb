# %%
import pandas as pd

# %%
dataset=pd.read_csv("D:\Datasets\global_power_plants.csv")
dataset
# Out:
# C:\Users\Aniket\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 16 columns):
# country code                     34936 non-null object
# country                          34936 non-null object
# name of powerplant               34936 non-null object
# capacity in MW                   34936 non-null object
# latitude                         34936 non-null float64
# longitude                        34936 non-null float64
# primary_fuel                     34936 non-null object
# secondary fuel                   1944 non-null object
# other_fuel 1                     276 non-null object
# other_fuel 2                     92 non-null object
# start date                       17447 non-null float64
# owner of plant                   20868 non-null object
# geolocation_source               34517 non-null object
# generation_gwh_2020              9659 non-null float64
# generation_data_source           11400 non-null object
# ...

# %%
dataset.describe()
# Out:
#            latitude     longitude    start date  generation_gwh_2020  \
# count  34936.000000  34936.000000  17447.000000          9659.000000
# mean      32.816637     -6.972803   1997.414823           423.922436
# std       22.638603     78.405850     23.397835          1698.506485
# min      -77.847000   -179.977700   1896.000000          -780.339000
# 25%       29.256475    -77.641550   1988.000000             2.751500
# 50%       39.727750     -2.127100   2007.000000            11.530000
# 75%       46.263125     49.502675   2014.000000           122.781498
# max       71.292000    179.388700   2020.000000         31920.368000
#
#        estimated_generation_gwh_2020
# count                   33138.000000
# mean                      716.443378
# std                      2484.361200
# min                         0.000000
# 25%                         8.180000
# 50%                        37.590000
# 75%                       229.565000
# max                     82810.770000

# %%
dataset.isnull().any()
# Out:
# country code                     False
# country                          False
# name of powerplant               False
# capacity in MW                   False
# latitude                         False
# longitude                        False
# primary_fuel                     False
# secondary fuel                    True
# other_fuel 1                      True
# other_fuel 2                      True
# start date                        True
# owner of plant                    True
# geolocation_source                True
# generation_gwh_2020               True
# generation_data_source            True
# estimated_generation_gwh_2020     True
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# country code                         0
# country                              0
# name of powerplant                   0
# capacity in MW                       0
# latitude                             0
# longitude                            0
# primary_fuel                         0
# secondary fuel                   32992
# other_fuel 1                     34660
# other_fuel 2                     34844
# start date                       17489
# owner of plant                   14068
# geolocation_source                 419
# generation_gwh_2020              25277
# generation_data_source           23536
# estimated_generation_gwh_2020     1798
# dtype: int64

# %% [markdown]
# # 1. Find the powerplants name who has less than 500 capacity of MW

# %%
dataset["capacity in MW"]=dataset["capacity in MW"].str.replace("$"," ")

# %%
dataset
# Out:
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# 19             DZA         Algeria
# 20             DZA         Algeria
# 21             DZA         Algeria
# 22             DZA         Algeria
# 23             DZA         Algeria
# 24             DZA         Algeria
# ...

# %%
dataset["capacity in MW"]=dataset["capacity in MW"].astype(float)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34936 entries, 0 to 34935
# Data columns (total 16 columns):
# country code                     34936 non-null object
# country                          34936 non-null object
# name of powerplant               34936 non-null object
# capacity in MW                   32768 non-null float64
# latitude                         34936 non-null float64
# longitude                        34936 non-null float64
# primary_fuel                     34936 non-null object
# secondary fuel                   1944 non-null object
# other_fuel 1                     276 non-null object
# other_fuel 2                     92 non-null object
# start date                       17447 non-null float64
# owner of plant                   20868 non-null object
# geolocation_source               34517 non-null object
# generation_gwh_2020              9659 non-null float64
# generation_data_source           11400 non-null object
# ...

# %%
dataset
# Out:
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# 19             DZA         Algeria
# 20             DZA         Algeria
# 21             DZA         Algeria
# 22             DZA         Algeria
# 23             DZA         Algeria
# 24             DZA         Algeria
# ...

# %%
a=dataset.loc[(dataset["capacity in MW"]<500),["capacity in MW","name of powerplant"]]

# %%
a
# Out:
#        capacity in MW                                 name of powerplant
# 0               33.00       Kajaki Hydroelectric Power Plant Afghanistan
# 1               10.00                                       Kandahar DOG
# 2               10.00                                       Kandahar JOL
# 3               66.00      Mahipar Hydroelectric Power Plant Afghanistan
# 4              100.00   Naghlu Dam Hydroelectric Power Plant Afghanistan
# 5               11.55  Nangarhar (Darunta) Hydroelectric Power Plant ...
# 6               42.00            Northwest Kabul Power Plant Afghanistan
# 7                6.00  Pul-e-Khumri Hydroelectric Power Plant Afghani...
# 8               22.00   Sarobi Dam Hydroelectric Power Plant Afghanistan
# 9               27.00                                         Bistrica 1
# 12               5.00                                         Lanabregas
# 13              24.00                                            Shkopet
# ...

# %% [markdown]
# # 2. Find the country which name is ended with stan set the respective country code with stan prefix

# %%
dataset=pd.read_csv("D:\Datasets\global_power_plants.csv")
dataset
# Out:
# C:\Users\Aniket\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# ...

# %%
dataset["country"].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Antarctica',
#        'Argentina', 'Armenia', 'Australia', 'Austria', 'Azerbaijan',
#        'Bahrain', 'Bangladesh', 'Belarus', 'Belgium', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Brunei Darussalam', 'Bulgaria', 'Burkina Faso', 'Burundi',
#        'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Central African Republic', 'Chile', 'China', 'Colombia', 'Congo',
#        'Costa Rica', 'Cote DIvoire', 'Croatia', 'Cuba', 'Cyprus',
#        'Czech Republic', 'Democratic Republic of the Congo', 'Denmark',
#        'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt', 'El Salvador',
#        'Equatorial Guinea', 'Eritrea', 'Estonia', 'Ethiopia', 'Fiji',
#        'Finland', 'France', 'French Guiana', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Greece', 'Guatemala', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Honduras', 'Hungary', 'Iceland',
# ...

# %%
a=[]
for x in dataset["country"]:
    pre=x[-4:]
    a.append(pre)
    print(pre)
# Out:
# stan
# stan
# stan
# stan
# stan
# stan
# stan
# stan
# stan
# ania
# ania
# ania
# ania
# ania
# ania
# ania
# ania
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# eria
# gola
# gola
# gola
# gola
# gola
# gola
# gola
# gola
# gola
# gola
# gola
# gola
# gola
# gola
# tica
# tica
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# tina
# ...

# %%
data1["country"].unique()
# Out:
# array(['Afghanistan', 'Kazakhstan', 'Kyrgyzstan', 'Pakistan', 'Tajikistan',
#        'Turkmenistan', 'Uzbekistan'], dtype=object)

# %%
new=[]
for x in data1["country code"]:
    a1=x
    a2="stan"
    a3=a2+a1
    new.append(a3)
    print(a3)
# Out:
# stanAFG
# stanAFG
# stanAFG
# stanAFG
# stanAFG
# stanAFG
# stanAFG
# stanAFG
# stanAFG
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKAZ
# stanKGZ
# stanKGZ
# stanKGZ
# stanKGZ
# stanKGZ
# stanKGZ
# stanKGZ
# stanKGZ
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# stanPAK
# ...

# %%
data1.insert(2,"modified_country_code",new)
data1
# Out:
#       country code       country modified_country_code modified_country code  \
# 0              AFG   Afghanistan               stanAFG               stanAFG
# 1              AFG   Afghanistan               stanAFG               stanAFG
# 2              AFG   Afghanistan               stanAFG               stanAFG
# 3              AFG   Afghanistan               stanAFG               stanAFG
# 4              AFG   Afghanistan               stanAFG               stanAFG
# 5              AFG   Afghanistan               stanAFG               stanAFG
# 6              AFG   Afghanistan               stanAFG               stanAFG
# 7              AFG   Afghanistan               stanAFG               stanAFG
# 8              AFG   Afghanistan               stanAFG               stanAFG
# 17033          KAZ    Kazakhstan               stanKAZ               stanKAZ
# 17034          KAZ    Kazakhstan               stanKAZ               stanKAZ
# ...

# %%
del data1["modified_country_code"]
data1
# Out:
#       country code       country modified_country code stanfix  \
# 0              AFG   Afghanistan               stanAFG    stan
# 1              AFG   Afghanistan               stanAFG    stan
# 2              AFG   Afghanistan               stanAFG    stan
# 3              AFG   Afghanistan               stanAFG    stan
# 4              AFG   Afghanistan               stanAFG    stan
# 5              AFG   Afghanistan               stanAFG    stan
# 6              AFG   Afghanistan               stanAFG    stan
# 7              AFG   Afghanistan               stanAFG    stan
# 8              AFG   Afghanistan               stanAFG    stan
# 17033          KAZ    Kazakhstan               stanKAZ    stan
# 17034          KAZ    Kazakhstan               stanKAZ    stan
# 17035          KAZ    Kazakhstan               stanKAZ    stan
# 17036          KAZ    Kazakhstan               stanKAZ    stan
# 17037          KAZ    Kazakhstan               stanKAZ    stan
# ...

# %% [markdown]
# # 3. Take Austrailia, India, USA top 5 highest capacity of MW power plants.

# %%
dataset=pd.read_csv("D:\Datasets\global_power_plants.csv")
dataset
# Out:
# C:\Users\Aniket\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# ...

# %%
dataset["capacity in MW"]=dataset["capacity in MW"].str.replace("$"," ")
dataset
# Out:
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# 19             DZA         Algeria
# 20             DZA         Algeria
# 21             DZA         Algeria
# 22             DZA         Algeria
# 23             DZA         Algeria
# 24             DZA         Algeria
# ...

# %%
dataset["capacity in MW"]=dataset["capacity in MW"].astype(float)
dataset
# Out:
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# 19             DZA         Algeria
# 20             DZA         Algeria
# 21             DZA         Algeria
# 22             DZA         Algeria
# 23             DZA         Algeria
# 24             DZA         Algeria
# ...

# %%
a1=dataset.loc[(dataset["country"]=="Australia"),["country","capacity in MW"]]
a1
# Out:
#        country  capacity in MW
# 336  Australia           1.000
# 337  Australia          21.600
# 338  Australia           4.000
# 339  Australia          50.000
# 340  Australia         165.000
# 341  Australia           3.600
# 342  Australia          55.600
# 343  Australia         240.000
# 344  Australia          32.000
# 345  Australia          94.000
# 346  Australia           3.000
# 347  Australia          12.850
# 348  Australia           2.000
# 349  Australia          88.000
# 350  Australia          37.000
# 351  Australia          20.000
# 352  Australia          10.900
# 353  Australia          60.000
# 354  Australia          79.900
# 355  Australia        2640.000
# 356  Australia           1.000
# 357  Australia         115.000
# 358  Australia         240.000
# 359  Australia          10.000
# 360  Australia           7.200
# 361  Australia          87.000
# 362  Australia           1.300
# 363  Australia           9.900
# 364  Australia          70.000
# ...

# %%
s=a1.sort_values(by=["capacity in MW"],ascending=False)

# %%
final=a1.loc[[355,564,572,475,499],["country","capacity in MW"]]
final
# Out:
#        country  capacity in MW
# 355  Australia          2640.0
# 564  Australia          2200.0
# 572  Australia          2180.0
# 475  Australia          1680.0
# 499  Australia          1600.0

# %%
a2=dataset.loc[(dataset["country"]=="India"),["country","capacity in MW"]]
a2
# Out:
#       country  capacity in MW
# 14052   India            2.50
# 14053   India           98.00
# 14054   India           39.20
# 14055   India          135.00
# 14056   India         1800.00
# 14057   India          250.00
# 14058   India           60.00
# 14059   India          192.00
# 14060   India          290.00
# 14061   India          210.00
# 14062   India         1350.00
# 14063   India          134.00
# 14064   India         1200.00
# 14065   India           16.95
# 14066   India         2630.00
# 14067   India          419.33
# 14068   India          600.00
# 14069   India         1200.00
# 14070   India           10.00
# 14071   India           17.00
# 14072   India           24.00
# 14073   India          652.00
# 14074   India          600.00
# 14075   India           46.00
# 14076   India           50.00
# 14077   India            5.50
# 14078   India           15.00
# 14079   India           15.00
# 14080   India           20.00
# 14081   India           22.00
# ...

# %%
a3=a2.sort_values(by=["capacity in MW"],ascending=False)
a3
# Out:
#       country  capacity in MW
# 15586   India         4760.00
# 14929   India         4620.00
# 14930   India         4000.00
# 15312   India         3960.00
# 15473   India         3300.00
# 15240   India         3000.00
# 15451   India         3000.00
# 15340   India         2980.00
# 14312   India         2920.00
# 14066   India         2630.00
# 14705   India         2600.00
# 15251   India         2600.00
# 15419   India         2520.00
# 14716   India         2400.00
# 14704   India         2400.00
# 15453   India         2400.00
# 14652   India         2340.00
# 14918   India         2320.00
# 14316   India         2320.00
# 14477   India         2100.00
# 15335   India         2000.00
# 14733   India         2000.00
# 14840   India         2000.00
# 15338   India         2000.00
# 15141   India         1980.00
# 14852   India         1980.00
# 15452   India         1980.00
# 15236   India         1967.08
# 14714   India         1956.00
# 14393   India         1820.00
# ...

# %%
a3.head(5)
# Out:
#       country  capacity in MW
# 15586   India          4760.0
# 14929   India          4620.0
# 14930   India          4000.0
# 15312   India          3960.0
# 15473   India          3300.0

# %%
final1=a2.loc[[15586,14929,14930,15312,15473],["country","capacity in MW"]]
final1
# Out:
#       country  capacity in MW
# 15586   India          4760.0
# 14929   India          4620.0
# 14930   India          4000.0
# 15312   India          3960.0
# 15473   India          3300.0

# %%
a3=dataset.loc[(dataset["country"]=="United States of America"),["country","capacity in MW"]]
a3
# Out:
#                         country  capacity in MW
# 24710  United States of America             2.0
# 24711  United States of America             5.0
# 24712  United States of America             3.0
# 24713  United States of America             1.9
# 24714  United States of America             2.0
# 24715  United States of America             1.3
# 24716  United States of America             3.8
# 24717  United States of America             4.2
# 24718  United States of America             1.3
# 24719  United States of America             1.9
# 24720  United States of America             2.4
# 24721  United States of America             2.0
# 24722  United States of America             3.0
# 24723  United States of America             1.2
# 24724  United States of America             1.5
# 24725  United States of America             1.3
# 24726  United States of America             2.0
# 24727  United States of America             2.0
# 24728  United States of America             4.9
# ...

# %%
a3.sort_values(by=["capacity in MW"],ascending=False)
# Out:
#                         country  capacity in MW
# 28190  United States of America          6809.0
# 31208  United States of America          4209.6
# 32391  United States of America          3564.0
# 25747  United States of America          3498.6
# 25851  United States of America          3494.0
# 26837  United States of America          3449.0
# 28079  United States of America          3339.5
# 30342  United States of America          3293.1
# 29923  United States of America          2951.2
# 29104  United States of America          2932.6
# 31304  United States of America          2876.4
# 25369  United States of America          2862.0
# 29029  United States of America          2848.4
# 29053  United States of America          2822.0
# 27765  United States of America          2680.9
# 30934  United States of America          2666.7
# 32034  United States of America          2600.0
# 26841  United States of America          2600.0
# 28007  United States of America          2600.0
# ...

# %%
final2=a3.loc[[28190,31208,32391,25747,25851],["country","capacity in MW"]]
final2
# Out:
#                         country  capacity in MW
# 28190  United States of America          6809.0
# 31208  United States of America          4209.6
# 32391  United States of America          3564.0
# 25747  United States of America          3498.6
# 25851  United States of America          3494.0

# %%
table=pd.concat((final,final1,final2))
table
# Out:
#                         country  capacity in MW
# 355                   Australia          2640.0
# 564                   Australia          2200.0
# 572                   Australia          2180.0
# 475                   Australia          1680.0
# 499                   Australia          1600.0
# 15586                     India          4760.0
# 14929                     India          4620.0
# 14930                     India          4000.0
# 15312                     India          3960.0
# 15473                     India          3300.0
# 28190  United States of America          6809.0
# 31208  United States of America          4209.6
# 32391  United States of America          3564.0
# 25747  United States of America          3498.6
# 25851  United States of America          3494.0

# %% [markdown]
# # 4. Show those countries in assending order who has primary fuel.

# %%
dataset=pd.read_csv("D:\Datasets\global_power_plants.csv")
dataset
# Out:
# C:\Users\Aniket\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# ...

# %%
z=dataset[["primary_fuel"]]
z
# Out:
#       primary_fuel
# 0            Hydro
# 1            Solar
# 2            Solar
# 3            Hydro
# 4            Hydro
# 5            Hydro
# 6              Gas
# 7            Hydro
# 8            Hydro
# 9            Hydro
# 10           Hydro
# 11           Hydro
# 12           Hydro
# 13           Hydro
# 14           Hydro
# 15           Hydro
# 16           Other
# 17           Solar
# 18           Solar
# 19             Gas
# 20           Solar
# 21           Solar
# 22           Solar
# 23           Solar
# 24           Solar
# 25             Gas
# 26           Solar
# 27             Gas
# 28           Solar
# 29             Gas
# ...            ...
# 34906         Coal
# 34907         Coal
# 34908        Hydro
# 34909        Hydro
# 34910        Hydro
# 34911          Oil
# 34912          Oil
# 34913          Oil
# 34914          Oil
# 34915          Oil
# 34916          Oil
# 34917          Gas
# 34918          Oil
# 34919          Oil
# 34920        Hydro
# ...

# %%
z.sort_values("primary_fuel")
# Out:
#       primary_fuel
# 1345       Biomass
# 2186       Biomass
# 2187       Biomass
# 2188       Biomass
# 1161       Biomass
# 4307       Biomass
# 1159       Biomass
# 27064      Biomass
# 2189       Biomass
# 3277       Biomass
# 2184       Biomass
# 2193       Biomass
# 3268       Biomass
# 2200       Biomass
# 3267       Biomass
# 2202       Biomass
# 3266       Biomass
# 3265       Biomass
# 3264       Biomass
# 3263       Biomass
# 3261       Biomass
# 2198       Biomass
# 2183       Biomass
# 2182       Biomass
# 2180       Biomass
# 31182      Biomass
# 3295       Biomass
# 1192       Biomass
# 31172      Biomass
# 3293       Biomass
# ...            ...
# 11056         Wind
# 11057         Wind
# 26914         Wind
# 26917         Wind
# 30726         Wind
# 20851         Wind
# 30743         Wind
# 30745         Wind
# 30765         Wind
# 4402          Wind
# 8740          Wind
# 20992         Wind
# 6898          Wind
# 20989         Wind
# 11456         Wind
# ...

# %% [markdown]
# # 5. Find country who has capacity of MW between 200 to 800 and increase the capacity of MW with 10%.

# %%
dataset=pd.read_csv("D:\Datasets\global_power_plants.csv")
dataset
# Out:
# C:\Users\Aniket\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# ...

# %%
dataset[["country","capacity in MW"]]
# Out:
#               country capacity in MW
# 0         Afghanistan           $ 33
# 1         Afghanistan             10
# 2         Afghanistan             10
# 3         Afghanistan             66
# 4         Afghanistan            100
# 5         Afghanistan          11.55
# 6         Afghanistan             42
# 7         Afghanistan              6
# 8         Afghanistan             22
# 9             Albania             27
# 10            Albania            500
# 11            Albania            600
# 12            Albania              5
# 13            Albania             24
# 14            Albania             25
# 15            Albania            250
# 16            Albania             98
# 17            Algeria             20
# 18            Algeria             20
# 19            Algeria            520
# 20            Algeria             20
# 21            Algeria             20
# 22            Algeria             53
# 23            Algeria             20
# ...

# %%
dataset["capacity in MW"]=dataset["capacity in MW"].str.replace("$"," ")
dataset
# Out:
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# 19             DZA         Algeria
# 20             DZA         Algeria
# 21             DZA         Algeria
# 22             DZA         Algeria
# 23             DZA         Algeria
# 24             DZA         Algeria
# ...

# %%
dataset["capacity in MW"]=dataset["capacity in MW"].astype(float)
dataset
# Out:
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# 19             DZA         Algeria
# 20             DZA         Algeria
# 21             DZA         Algeria
# 22             DZA         Algeria
# 23             DZA         Algeria
# 24             DZA         Algeria
# ...

# %%
a=dataset.loc[(dataset["capacity in MW"]>200) & (dataset["capacity in MW"]<800),["country","capacity in MW"]]
a
# Out:
#                         country  capacity in MW
# 10                      Albania           500.0
# 11                      Albania           600.0
# 15                      Albania           250.0
# 19                      Algeria           520.0
# 27                      Algeria           560.0
# 30                      Algeria           450.0
# 31                      Algeria           450.0
# 34                      Algeria           292.0
# 37                      Algeria           418.0
# 39                      Algeria           600.0
# 41                      Algeria           492.0
# 47                      Algeria           588.0
# 48                      Algeria           345.0
# 51                      Algeria           396.0
# 58                      Algeria           672.0
# 62                      Algeria           465.0
# 63                      Algeria           484.0
# 66                      Algeria           262.0
# 69                      Algeria           300.0
# ...

# %%
increase=a["capacity in MW"]+0.01
increase
# Out:
# 10       500.01
# 11       600.01
# 15       250.01
# 19       520.01
# 27       560.01
# 30       450.01
# 31       450.01
# 34       292.01
# 37       418.01
# 39       600.01
# 41       492.01
# 47       588.01
# 48       345.01
# 51       396.01
# 58       672.01
# 62       465.01
# 63       484.01
# 66       262.01
# 69       300.01
# 71       600.01
# 79       520.01
# 92       479.21
# 101      370.01
# 102      745.01
# 119      620.01
# 120      540.01
# 122      673.61
# 124      280.01
# 125      643.01
# 126      361.01
#           ...
# 32361    285.61
# 32367    338.41
# 32378    212.01
# 32379    430.21
# 32433    207.61
# 32434    446.01
# 32450    469.01
# 32464    585.01
# 32466    570.01
# 32468    541.21
# 32477    204.01
# 32483    714.01
# 32492    632.01
# 32493    346.81
# 32508    228.71
# 32512    268.21
# 32578    261.01
# 32585    250.51
# 32592    260.11
# 32593    664.71
# 32597    623.01
# 32634    242.01
# 32641    547.51
# 32670    280.01
# ...

# %% [markdown]
# # 6. Those countries having primary fuel as coal & Oil increase 12% in current MW and Hydro decrease 7%.

# %%
dataset["capacity in MW"]=dataset["capacity in MW"].str.replace("$"," ")
dataset
# Out:
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# 19             DZA         Algeria
# 20             DZA         Algeria
# 21             DZA         Algeria
# 22             DZA         Algeria
# 23             DZA         Algeria
# 24             DZA         Algeria
# ...

# %%
dataset["capacity in MW"]=dataset["capacity in MW"].astype(float)
dataset
# Out:
#       country code         country  \
# 0              AFG     Afghanistan
# 1              AFG     Afghanistan
# 2              AFG     Afghanistan
# 3              AFG     Afghanistan
# 4              AFG     Afghanistan
# 5              AFG     Afghanistan
# 6              AFG     Afghanistan
# 7              AFG     Afghanistan
# 8              AFG     Afghanistan
# 9              ALB         Albania
# 10             ALB         Albania
# 11             ALB         Albania
# 12             ALB         Albania
# 13             ALB         Albania
# 14             ALB         Albania
# 15             ALB         Albania
# 16             ALB         Albania
# 17             DZA         Algeria
# 18             DZA         Algeria
# 19             DZA         Algeria
# 20             DZA         Algeria
# 21             DZA         Algeria
# 22             DZA         Algeria
# 23             DZA         Algeria
# 24             DZA         Algeria
# ...

# %%
ab=dataset[["country","capacity in MW","primary_fuel"]]
ab
# Out:
#               country  capacity in MW primary_fuel
# 0         Afghanistan           33.00        Hydro
# 1         Afghanistan           10.00        Solar
# 2         Afghanistan           10.00        Solar
# 3         Afghanistan           66.00        Hydro
# 4         Afghanistan          100.00        Hydro
# 5         Afghanistan           11.55        Hydro
# 6         Afghanistan           42.00          Gas
# 7         Afghanistan            6.00        Hydro
# 8         Afghanistan           22.00        Hydro
# 9             Albania           27.00        Hydro
# 10            Albania          500.00        Hydro
# 11            Albania          600.00        Hydro
# 12            Albania            5.00        Hydro
# 13            Albania           24.00        Hydro
# 14            Albania           25.00        Hydro
# 15            Albania          250.00        Hydro
# 16            Albania           98.00        Other
# ...

# %%
a1=ab.loc[(ab["primary_fuel"]=="Coal") | (ab["primary_fuel"]=="Oil"), ["capacity in MW","primary_fuel"]]
a1
# Out:
#        capacity in MW primary_fuel
# 76             22.800          Oil
# 81             16.260          Oil
# 83             58.000          Oil
# 84             18.500          Oil
# 85             10.000          Oil
# 89             11.340          Oil
# 90              6.600          Oil
# 96             25.000          Oil
# 98              1.904          Oil
# 103            31.000          Oil
# 104             5.736          Oil
# 106             2.096          Oil
# 107            31.900          Oil
# 108            27.600          Oil
# 109             1.415          Oil
# 112             1.070          Oil
# 113             4.182          Oil
# 114             5.728          Oil
# 115             7.075          Oil
# 116             4.675          Oil
# 119           620.000         Coal
# 121            11.228          Oil
# 126           361.000         Coal
# 128            30.440          Oil
# 129            25.000          Oil
# 134             5.000          Oil
# ...

# %%
a2=a1[["capacity in MW"]].fillna(0)
a2
# Out:
#        capacity in MW
# 76             22.800
# 81             16.260
# 83             58.000
# 84             18.500
# 85             10.000
# 89             11.340
# 90              6.600
# 96             25.000
# 98              1.904
# 103            31.000
# 104             5.736
# 106             2.096
# 107            31.900
# 108            27.600
# 109             1.415
# 112             1.070
# 113             4.182
# 114             5.728
# 115             7.075
# 116             4.675
# 119           620.000
# 121            11.228
# 126           361.000
# 128            30.440
# 129            25.000
# 134             5.000
# 137             2.372
# 140             1.400
# 141          1982.200
# 143             5.052
# ...               ...
# 34799           0.000
# 34802           0.000
# 34824           0.000
# 34832           0.000
# 34834           0.000
# 34838           0.000
# 34839           0.000
# 34849           0.000
# 34859           0.000
# ...

# %%
increase=a2[["capacity in MW"]]+0.12
increase
# Out:
#        capacity in MW
# 76             22.920
# 81             16.380
# 83             58.120
# 84             18.620
# 85             10.120
# 89             11.460
# 90              6.720
# 96             25.120
# 98              2.024
# 103            31.120
# 104             5.856
# 106             2.216
# 107            32.020
# 108            27.720
# 109             1.535
# 112             1.190
# 113             4.302
# 114             5.848
# 115             7.195
# 116             4.795
# 119           620.120
# 121            11.348
# 126           361.120
# 128            30.560
# 129            25.120
# 134             5.120
# 137             2.492
# 140             1.520
# 141          1982.320
# 143             5.172
# ...               ...
# 34799           0.120
# 34802           0.120
# 34824           0.120
# 34832           0.120
# 34834           0.120
# 34838           0.120
# 34839           0.120
# 34849           0.120
# 34859           0.120
# ...

# %%
s=ab[["capacity in MW","primary_fuel"]]
s
# Out:
#        capacity in MW primary_fuel
# 0               33.00        Hydro
# 1               10.00        Solar
# 2               10.00        Solar
# 3               66.00        Hydro
# 4              100.00        Hydro
# 5               11.55        Hydro
# 6               42.00          Gas
# 7                6.00        Hydro
# 8               22.00        Hydro
# 9               27.00        Hydro
# 10             500.00        Hydro
# 11             600.00        Hydro
# 12               5.00        Hydro
# 13              24.00        Hydro
# 14              25.00        Hydro
# 15             250.00        Hydro
# 16              98.00        Other
# 17              20.00        Solar
# 18              20.00        Solar
# 19             520.00          Gas
# 20              20.00        Solar
# 21              20.00        Solar
# 22              53.00        Solar
# 23              20.00        Solar
# 24              43.50        Solar
# 25              71.00          Gas
# ...

# %%
h=ab.loc[(ab["primary_fuel"]=="Hydro"), ["capacity in MW","primary_fuel"]]
h
# Out:
#        capacity in MW primary_fuel
# 0               33.00        Hydro
# 3               66.00        Hydro
# 4              100.00        Hydro
# 5               11.55        Hydro
# 7                6.00        Hydro
# 8               22.00        Hydro
# 9               27.00        Hydro
# 10             500.00        Hydro
# 11             600.00        Hydro
# 12               5.00        Hydro
# 13              24.00        Hydro
# 14              25.00        Hydro
# 15             250.00        Hydro
# 45              24.00        Hydro
# 77              14.60        Hydro
# 78             180.00        Hydro
# 79             520.00        Hydro
# 86              40.00        Hydro
# 88              16.00        Hydro
# 94             130.00        Hydro
# 95            1050.00        Hydro
# 99              50.70        Hydro
# 100            128.00        Hydro
# 105             38.40        Hydro
# 110            102.00        Hydro
# 111            120.00        Hydro
# ...

# %%
f=h[["capacity in MW"]].fillna(0)
f
# Out:
#        capacity in MW
# 0               33.00
# 3               66.00
# 4              100.00
# 5               11.55
# 7                6.00
# 8               22.00
# 9               27.00
# 10             500.00
# 11             600.00
# 12               5.00
# 13              24.00
# 14              25.00
# 15             250.00
# 45              24.00
# 77              14.60
# 78             180.00
# 79             520.00
# 86              40.00
# 88              16.00
# 94             130.00
# 95            1050.00
# 99              50.70
# 100            128.00
# 105             38.40
# 110            102.00
# 111            120.00
# 117             60.00
# 118             17.28
# 133            121.40
# 136              5.78
# ...               ...
# 34878            0.00
# 34879            0.00
# 34880            0.00
# 34881            0.00
# 34882            0.00
# 34883            0.00
# 34884            0.00
# 34885            0.00
# 34886            0.00
# ...

# %%
decrease=f[["capacity in MW"]]-0.07
decrease
# Out:
#        capacity in MW
# 0               32.93
# 3               65.93
# 4               99.93
# 5               11.48
# 7                5.93
# 8               21.93
# 9               26.93
# 10             499.93
# 11             599.93
# 12               4.93
# 13              23.93
# 14              24.93
# 15             249.93
# 45              23.93
# 77              14.53
# 78             179.93
# 79             519.93
# 86              39.93
# 88              15.93
# 94             129.93
# 95            1049.93
# 99              50.63
# 100            127.93
# 105             38.33
# 110            101.93
# 111            119.93
# 117             59.93
# 118             17.21
# 133            121.33
# 136              5.71
# ...               ...
# 34878           -0.07
# 34879           -0.07
# 34880           -0.07
# 34881           -0.07
# 34882           -0.07
# 34883           -0.07
# 34884           -0.07
# 34885           -0.07
# 34886           -0.07
# ...
