# %%
import pandas as pd

# %%
dataset=pd.read_csv("D:\Datasets\wine-quality-white-and-red.csv")

# %%
dataset
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 1     white            6.3             0.300         0.34            1.60
# 2     white            8.1             0.280         0.40            6.90
# 3     white            7.2             0.230         0.32            8.50
# 4     white            7.2             0.230         0.32            8.50
# 5     white            8.1             0.280         0.40            6.90
# 6     white            6.2             0.320         0.16            7.00
# 7     white            7.0             0.270         0.36           20.70
# 8     white            6.3             0.300         0.34            1.60
# 9     white            8.1             0.220         0.43            1.50
# 10    white            8.1             0.270         0.41            1.45
# 11    white            8.6             0.230         0.40            4.20
# ...

# %% [markdown]
# # Information

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
# type                    6497 non-null object
# fixed acidity           6497 non-null float64
# volatile acidity        6497 non-null float64
# citric acid             6497 non-null float64
# residual sugar          6497 non-null float64
# chlorides               6497 non-null float64
# free sulfur dioxide     6497 non-null float64
# total sulfur dioxide    6497 non-null float64
# density                 6497 non-null float64
# pH                      6497 non-null float64
# sulphates               6497 non-null float64
# alcohol                 6497 non-null float64
# quality                 6497 non-null int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 659.9+ KB

# %% [markdown]
# # Describe

# %%
dataset.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# # isnull().any()

# %%
dataset.isnull().any()
# Out:
# type                    False
# fixed acidity           False
# volatile acidity        False
# citric acid             False
# residual sugar          False
# chlorides               False
# free sulfur dioxide     False
# total sulfur dioxide    False
# density                 False
# pH                      False
# sulphates               False
# alcohol                 False
# quality                 False
# dtype: bool

# %% [markdown]
# # isnull().sum()

# %%
dataset.isnull().sum()
# Out:
# type                    0
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# # unique()

# %%
dataset["sulphates"].unique()
# Out:
# array([ 0.45,  0.49,  0.44,  0.4 ,  0.47,  0.56,  0.53,  0.63,  0.52,
#         0.67,  0.55,  0.36,  0.39,  0.5 ,  0.35,  0.48,  0.51,  0.71,
#         0.37,  0.42,  0.28,  0.34,  0.46,  0.58,  0.38,  0.54,  0.64,
#         0.6 ,  0.65,  0.77,  0.41,  0.3 ,  0.59,  0.57,  0.43,  0.32,
#         0.84,  0.33,  0.29,  0.27,  0.68,  0.66,  0.61,  0.74,  0.79,
#         0.7 ,  0.62,  0.85,  0.76,  0.75,  0.78,  0.69,  0.72,  0.73,
#         0.96,  0.97,  0.82,  0.95,  0.9 ,  0.88,  0.31,  0.25,  0.8 ,
#         0.87,  0.86,  0.81,  0.92,  0.26,  0.98,  1.06,  1.  ,  0.89,
#         0.94,  0.99,  0.22,  0.23,  0.83,  1.01,  1.08,  1.56,  0.93,
#         1.28,  0.91,  1.2 ,  1.12,  1.14,  1.95,  1.22,  1.98,  1.31,
#         2.  ,  1.59,  1.02,  1.03,  1.61,  1.09,  1.26,  1.36,  1.18,
#         1.13,  1.04,  1.11,  1.07,  1.05,  1.17,  1.62,  1.34,  1.16,
#         1.1 ,  1.15,  1.33])

# %% [markdown]
# # value_counts()

# %%
dataset["sulphates"].value_counts()
# Out:
# 0.50    276
# 0.46    243
# 0.54    235
# 0.44    232
# 0.38    214
# 0.48    208
# 0.52    203
# 0.49    197
# 0.47    191
# 0.45    190
# 0.42    186
# 0.53    186
# 0.40    172
# 0.43    169
# 0.56    168
# 0.58    167
# 0.51    166
# 0.39    157
# 0.60    157
# 0.55    152
# 0.59    148
# 0.41    139
# 0.57    138
# 0.37    131
# 0.62    129
# 0.36    120
# 0.64    113
# 0.63     96
# 0.61     90
# 0.35     85
#        ...
# 1.05      3
# 1.28      2
# 1.10      2
# 1.13      2
# 1.01      2
# 1.03      2
# 1.95      2
# 1.00      2
# 1.04      2
# 1.07      2
# 1.14      2
# 1.34      1
# 2.00      1
# 1.16      1
# 1.61      1
# 1.15      1
# 1.22      1
# 1.31      1
# 1.09      1
# 0.23      1
# 0.22      1
# 1.11      1
# 1.20      1
# 1.98      1
# 1.26      1
# 1.59      1
# 1.12      1
# 1.33      1
# 1.56      1
# 1.62      1
# Name: sulphates, Length: 111, dtype: int64

# %%
dataset.count()
# Out:
# type                    6497
# fixed acidity           6497
# volatile acidity        6497
# citric acid             6497
# residual sugar          6497
# chlorides               6497
# free sulfur dioxide     6497
# total sulfur dioxide    6497
# density                 6497
# pH                      6497
# sulphates               6497
# alcohol                 6497
# quality                 6497
# dtype: int64

# %%
dataset["alcohol"].count()
# Out:
# 6497

# %% [markdown]
# # iloc

# %%
dataset
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 1     white            6.3             0.300         0.34            1.60
# 2     white            8.1             0.280         0.40            6.90
# 3     white            7.2             0.230         0.32            8.50
# 4     white            7.2             0.230         0.32            8.50
# 5     white            8.1             0.280         0.40            6.90
# 6     white            6.2             0.320         0.16            7.00
# 7     white            7.0             0.270         0.36           20.70
# 8     white            6.3             0.300         0.34            1.60
# 9     white            8.1             0.220         0.43            1.50
# 10    white            8.1             0.270         0.41            1.45
# 11    white            8.6             0.230         0.40            4.20
# ...

# %%
a=dataset.iloc[2:5422,3:9]

# %%
a
# Out:
#       citric acid  residual sugar  chlorides  free sulfur dioxide  \
# 2            0.40            6.90      0.050                 30.0
# 3            0.32            8.50      0.058                 47.0
# 4            0.32            8.50      0.058                 47.0
# 5            0.40            6.90      0.050                 30.0
# 6            0.16            7.00      0.045                 30.0
# 7            0.36           20.70      0.045                 45.0
# 8            0.34            1.60      0.049                 14.0
# 9            0.43            1.50      0.044                 28.0
# 10           0.41            1.45      0.033                 11.0
# 11           0.40            4.20      0.035                 17.0
# 12           0.37            1.20      0.040                 16.0
# 13           0.40            1.50      0.044                 48.0
# 14           0.62           19.25      0.040                 41.0
# ...

# %% [markdown]
# # Negative indexing

# %%
a=dataset.iloc[:-3,-2:]

# %%
a
# Out:
#       alcohol  quality
# 0         8.8        6
# 1         9.5        6
# 2        10.1        6
# 3         9.9        6
# 4         9.9        6
# 5        10.1        6
# 6         9.6        6
# 7         8.8        6
# 8         9.5        6
# 9        11.0        6
# 10       12.0        5
# 11        9.7        5
# 12       10.8        5
# 13       12.4        7
# 14        9.7        5
# 15       11.4        7
# 16        9.6        6
# 17       12.8        8
# 18       11.3        6
# 19        9.5        5
# 20       12.8        8
# 21       11.0        7
# 22       10.5        8
# 23        9.3        5
# 24       10.0        6
# 25       10.4        6
# 26       10.0        6
# 27       10.5        6
# 28       11.6        6
# 29       12.3        7
# ...       ...      ...
# 6464     11.2        6
# 6465     10.1        5
# 6466      9.2        5
# 6467     11.5        6
# 6468     12.4        6
# 6469     11.1        6
# 6470      9.5        5
# 6471     12.5        6
# ...

# %% [markdown]
# # loc

# %%
dataset
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 1     white            6.3             0.300         0.34            1.60
# 2     white            8.1             0.280         0.40            6.90
# 3     white            7.2             0.230         0.32            8.50
# 4     white            7.2             0.230         0.32            8.50
# 5     white            8.1             0.280         0.40            6.90
# 6     white            6.2             0.320         0.16            7.00
# 7     white            7.0             0.270         0.36           20.70
# 8     white            6.3             0.300         0.34            1.60
# 9     white            8.1             0.220         0.43            1.50
# 10    white            8.1             0.270         0.41            1.45
# 11    white            8.6             0.230         0.40            4.20
# ...

# %%
dataset.loc[(dataset["citric acid"]>=0.36)]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0              0.27         0.36           20.70
# 2     white            8.1              0.28         0.40            6.90
# 5     white            8.1              0.28         0.40            6.90
# 7     white            7.0              0.27         0.36           20.70
# 9     white            8.1              0.22         0.43            1.50
# 10    white            8.1              0.27         0.41            1.45
# 11    white            8.6              0.23         0.40            4.20
# 12    white            7.9              0.18         0.37            1.20
# 13    white            6.6              0.16         0.40            1.50
# 14    white            8.3              0.42         0.62           19.25
# 15    white            6.6              0.17         0.38            1.50
# 17    white            6.2              0.66         0.48            1.20
# ...

# %%
dataset.loc[(dataset["citric acid"]>=0.36) & (dataset["chlorides"]>=0.040)]
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0              0.27         0.36           20.70
# 2     white            8.1              0.28         0.40            6.90
# 5     white            8.1              0.28         0.40            6.90
# 7     white            7.0              0.27         0.36           20.70
# 9     white            8.1              0.22         0.43            1.50
# 12    white            7.9              0.18         0.37            1.20
# 13    white            6.6              0.16         0.40            1.50
# 14    white            8.3              0.42         0.62           19.25
# 22    white            6.8              0.26         0.42            1.70
# 24    white            6.6              0.27         0.41            1.30
# 27    white            7.0              0.28         0.39            8.70
# 28    white            7.4              0.27         0.48            1.10
# ...

# %% [markdown]
# # it matches the conditiond and only shows the these columns

# %%
dataset.loc[(dataset["citric acid"]>=0.36) & (dataset["chlorides"]>=0.040),["citric acid","chlorides"]]
# Out:
#       citric acid  chlorides
# 0            0.36      0.045
# 2            0.40      0.050
# 5            0.40      0.050
# 7            0.36      0.045
# 9            0.43      0.044
# 12           0.37      0.040
# 13           0.40      0.044
# 14           0.62      0.040
# 22           0.42      0.049
# 24           0.41      0.052
# 27           0.39      0.051
# 28           0.48      0.047
# 30           0.39      0.044
# 32           0.36      0.050
# 35           0.43      0.080
# 38           0.39      0.057
# 39           0.39      0.057
# 40           0.39      0.172
# 41           0.39      0.173
# 54           0.59      0.147
# 70           0.43      0.056
# 73           0.46      0.054
# 76           0.36      0.043
# 84           0.61      0.045
# 85           0.62      0.044
# 86           0.63      0.044
# 88           0.61      0.045
# 89           0.62      0.044
# 90           0.63      0.044
# 91           0.43      0.049
# ...           ...        ...
# ...

# %% [markdown]
# # It will shows the only these columns

# %%
dataset[["citric acid","chlorides"]]
# Out:
#       citric acid  chlorides
# 0            0.36      0.045
# 1            0.34      0.049
# 2            0.40      0.050
# 3            0.32      0.058
# 4            0.32      0.058
# 5            0.40      0.050
# 6            0.16      0.045
# 7            0.36      0.045
# 8            0.34      0.049
# 9            0.43      0.044
# 10           0.41      0.033
# 11           0.40      0.035
# 12           0.37      0.040
# 13           0.40      0.044
# 14           0.62      0.040
# 15           0.38      0.032
# 16           0.04      0.046
# 17           0.48      0.029
# 18           0.42      0.033
# 19           0.14      0.044
# 20           0.48      0.029
# 21           0.38      0.038
# 22           0.42      0.049
# 23           0.14      0.074
# 24           0.41      0.052
# 25           0.32      0.046
# 26           0.35      0.052
# 27           0.39      0.051
# 28           0.48      0.047
# 29           0.36      0.033
# ...           ...        ...
# ...

# %% [markdown]
# # It will shows the only these rows and columns

# %%
dataset.loc[[5,89,3,88,789],["free sulfur dioxide","total sulfur dioxide","density","pH","sulphates"]]
# Out:
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 5                   30.0                  97.0  0.99510  3.26       0.44
# 89                  52.0                 152.0  0.99750  3.12       0.46
# 3                   47.0                 186.0  0.99560  3.19       0.40
# 88                  54.0                 155.0  0.99740  3.11       0.45
# 789                 31.0                 119.0  0.99815  3.27       0.30

# %% [markdown]
# # replace

# %%
dataset
# Out:
#        type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     white            7.0             0.270         0.36           20.70
# 1     white            6.3             0.300         0.34            1.60
# 2     white            8.1             0.280         0.40            6.90
# 3     white            7.2             0.230         0.32            8.50
# 4     white            7.2             0.230         0.32            8.50
# 5     white            8.1             0.280         0.40            6.90
# 6     white            6.2             0.320         0.16            7.00
# 7     white            7.0             0.270         0.36           20.70
# 8     white            6.3             0.300         0.34            1.60
# 9     white            8.1             0.220         0.43            1.50
# 10    white            8.1             0.270         0.41            1.45
# 11    white            8.6             0.230         0.40            4.20
# ...

# %%
a=dataset["type"].replace("white","red",inplace=True)

# %%
dataset
# Out:
#      type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0     red            7.0             0.270         0.36           20.70
# 1     red            6.3             0.300         0.34            1.60
# 2     red            8.1             0.280         0.40            6.90
# 3     red            7.2             0.230         0.32            8.50
# 4     red            7.2             0.230         0.32            8.50
# 5     red            8.1             0.280         0.40            6.90
# 6     red            6.2             0.320         0.16            7.00
# 7     red            7.0             0.270         0.36           20.70
# 8     red            6.3             0.300         0.34            1.60
# 9     red            8.1             0.220         0.43            1.50
# 10    red            8.1             0.270         0.41            1.45
# 11    red            8.6             0.230         0.40            4.20
# ...

# %% [markdown]
# # drop

# %%
a=dataset[["pH","sulphates","alcohol","quality"]]

# %%
a
# Out:
#         pH  sulphates  alcohol  quality
# 0     3.00       0.45      8.8        6
# 1     3.30       0.49      9.5        6
# 2     3.26       0.44     10.1        6
# 3     3.19       0.40      9.9        6
# 4     3.19       0.40      9.9        6
# 5     3.26       0.44     10.1        6
# 6     3.18       0.47      9.6        6
# 7     3.00       0.45      8.8        6
# 8     3.30       0.49      9.5        6
# 9     3.22       0.45     11.0        6
# 10    2.99       0.56     12.0        5
# 11    3.14       0.53      9.7        5
# 12    3.18       0.63     10.8        5
# 13    3.54       0.52     12.4        7
# 14    2.98       0.67      9.7        5
# 15    3.25       0.55     11.4        7
# 16    3.24       0.36      9.6        6
# 17    3.33       0.39     12.8        8
# 18    3.12       0.53     11.3        6
# 19    3.22       0.50      9.5        5
# 20    3.33       0.39     12.8        8
# 21    3.17       0.35     11.0        7
# ...

# %%
b=a.drop(columns=["pH"],inplace=False)

# %%
b
# Out:
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# 5          0.44     10.1        6
# 6          0.47      9.6        6
# 7          0.45      8.8        6
# 8          0.49      9.5        6
# 9          0.45     11.0        6
# 10         0.56     12.0        5
# 11         0.53      9.7        5
# 12         0.63     10.8        5
# 13         0.52     12.4        7
# 14         0.67      9.7        5
# 15         0.55     11.4        7
# 16         0.36      9.6        6
# 17         0.39     12.8        8
# 18         0.53     11.3        6
# 19         0.50      9.5        5
# 20         0.39     12.8        8
# 21         0.35     11.0        7
# 22         0.48     10.5        8
# 23         0.51      9.3        5
# 24         0.47     10.0        6
# 25         0.50     10.4        6
# ...

# %% [markdown]
# # to_csv

# %%
b.to_csv("Anusha dataset.csv",index=False)

# %%
v=pd.read_csv("Anusha dataset.csv")
v
# Out:
#       sulphates  alcohol  quality
# 0          0.45      8.8        6
# 1          0.49      9.5        6
# 2          0.44     10.1        6
# 3          0.40      9.9        6
# 4          0.40      9.9        6
# 5          0.44     10.1        6
# 6          0.47      9.6        6
# 7          0.45      8.8        6
# 8          0.49      9.5        6
# 9          0.45     11.0        6
# 10         0.56     12.0        5
# 11         0.53      9.7        5
# 12         0.63     10.8        5
# 13         0.52     12.4        7
# 14         0.67      9.7        5
# 15         0.55     11.4        7
# 16         0.36      9.6        6
# 17         0.39     12.8        8
# 18         0.53     11.3        6
# 19         0.50      9.5        5
# 20         0.39     12.8        8
# 21         0.35     11.0        7
# 22         0.48     10.5        8
# 23         0.51      9.3        5
# 24         0.47     10.0        6
# 25         0.50     10.4        6
# ...

# %% [markdown]
# # fillna()
