# %%
import pandas as pd
import numpy as np

# %%
dataset=pd.read_csv("D:\Datasets\covid_19_india.csv")
dataset
# Out:
#          Sno        Date      Time                      State/UnionTerritory  \
# 0          1  30/01/2020  06:00 PM                                    Kerala
# 1          2  31/01/2020  06:00 PM                                    Kerala
# 2          3  01/02/2020  06:00 PM                                    Kerala
# 3          4  02/02/2020  06:00 PM                                    Kerala
# 4          5  03/02/2020  06:00 PM                                    Kerala
# 5          6  04/02/2020  06:00 PM                                    Kerala
# 6          7  05/02/2020  06:00 PM                                    Kerala
# 7          8  06/02/2020  06:00 PM                                    Kerala
# 8          9  07/02/2020  06:00 PM                                    Kerala
# 9         10  08/02/2020  06:00 PM                                    Kerala
# 10        11  09/02/2020  06:00 PM                                    Kerala
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
# Sno                         18110 non-null int64
# Date                        18110 non-null object
# Time                        18110 non-null object
# State/UnionTerritory        18110 non-null object
# ConfirmedIndianNational     18110 non-null object
# ConfirmedForeignNational    18110 non-null object
# Cured                       18110 non-null int64
# Deaths                      18110 non-null int64
# Confirmed                   18110 non-null int64
# dtypes: int64(4), object(5)
# memory usage: 1.2+ MB

# %%
dataset.describe()
# Out:
#                 Sno         Cured         Deaths     Confirmed
# count  18110.000000  1.811000e+04   18110.000000  1.811000e+04
# mean    9055.500000  2.786375e+05    4052.402264  3.010314e+05
# std     5228.051023  6.148909e+05   10919.076411  6.561489e+05
# min        1.000000  0.000000e+00       0.000000  0.000000e+00
# 25%     4528.250000  3.360250e+03      32.000000  4.376750e+03
# 50%     9055.500000  3.336400e+04     588.000000  3.977350e+04
# 75%    13582.750000  2.788698e+05    3643.750000  3.001498e+05
# max    18110.000000  6.159676e+06  134201.000000  6.363442e+06

# %%
dataset.isnull().any()
# Out:
# Sno                         False
# Date                        False
# Time                        False
# State/UnionTerritory        False
# ConfirmedIndianNational     False
# ConfirmedForeignNational    False
# Cured                       False
# Deaths                      False
# Confirmed                   False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# Sno                         0
# Date                        0
# Time                        0
# State/UnionTerritory        0
# ConfirmedIndianNational     0
# ConfirmedForeignNational    0
# Cured                       0
# Deaths                      0
# Confirmed                   0
# dtype: int64

# %%
dataset["Cured"].unique()
# Out:
# array([      0,       3,       1, ...,  334650, 1685492, 1506532], dtype=int64)

# %% [markdown]
# # Formate 1(date_time)

# %%
dataset["Date"]=pd.to_datetime(dataset["Date"])

# %%
dataset
# Out:
#          Sno       Date      Time                      State/UnionTerritory  \
# 0          1 2020-01-30  06:00 PM                                    Kerala
# 1          2 2020-01-31  06:00 PM                                    Kerala
# 2          3 2020-01-02  06:00 PM                                    Kerala
# 3          4 2020-02-02  06:00 PM                                    Kerala
# 4          5 2020-03-02  06:00 PM                                    Kerala
# 5          6 2020-04-02  06:00 PM                                    Kerala
# 6          7 2020-05-02  06:00 PM                                    Kerala
# 7          8 2020-06-02  06:00 PM                                    Kerala
# 8          9 2020-07-02  06:00 PM                                    Kerala
# 9         10 2020-08-02  06:00 PM                                    Kerala
# 10        11 2020-09-02  06:00 PM                                    Kerala
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18110 entries, 0 to 18109
# Data columns (total 9 columns):
# Sno                         18110 non-null int64
# Date                        18110 non-null datetime64[ns]
# Time                        18110 non-null object
# State/UnionTerritory        18110 non-null object
# ConfirmedIndianNational     18110 non-null object
# ConfirmedForeignNational    18110 non-null object
# Cured                       18110 non-null int64
# Deaths                      18110 non-null int64
# Confirmed                   18110 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 1.2+ MB

# %%
start="2020-02-01"
end="2021-03-01"

# %%
a=dataset.loc[(dataset["Date"]>="2020-02-01") & (dataset["Date"]<="2021-03-01")]

# %%
a
# Out:
#          Sno       Date      Time                      State/UnionTerritory  \
# 3          4 2020-02-02  06:00 PM                                    Kerala
# 4          5 2020-03-02  06:00 PM                                    Kerala
# 5          6 2020-04-02  06:00 PM                                    Kerala
# 6          7 2020-05-02  06:00 PM                                    Kerala
# 7          8 2020-06-02  06:00 PM                                    Kerala
# 8          9 2020-07-02  06:00 PM                                    Kerala
# 9         10 2020-08-02  06:00 PM                                    Kerala
# 10        11 2020-09-02  06:00 PM                                    Kerala
# 11        12 2020-10-02  06:00 PM                                    Kerala
# 12        13 2020-11-02  06:00 PM                                    Kerala
# 13        14 2020-12-02  06:00 PM                                    Kerala
# ...

# %%
a["Date"].unique()
# Out:
# array(['2020-02-02T00:00:00.000000000', '2020-03-02T00:00:00.000000000',
#        '2020-04-02T00:00:00.000000000', '2020-05-02T00:00:00.000000000',
#        '2020-06-02T00:00:00.000000000', '2020-07-02T00:00:00.000000000',
#        '2020-08-02T00:00:00.000000000', '2020-09-02T00:00:00.000000000',
#        '2020-10-02T00:00:00.000000000', '2020-11-02T00:00:00.000000000',
#        '2020-12-02T00:00:00.000000000', '2020-02-13T00:00:00.000000000',
#        '2020-02-14T00:00:00.000000000', '2020-02-15T00:00:00.000000000',
#        '2020-02-16T00:00:00.000000000', '2020-02-17T00:00:00.000000000',
#        '2020-02-18T00:00:00.000000000', '2020-02-19T00:00:00.000000000',
#        '2020-02-20T00:00:00.000000000', '2020-02-21T00:00:00.000000000',
#        '2020-02-22T00:00:00.000000000', '2020-02-23T00:00:00.000000000',
#        '2020-02-24T00:00:00.000000000', '2020-02-25T00:00:00.000000000',
#        '2020-02-26T00:00:00.000000000', '2020-02-27T00:00:00.000000000',
# ...

# %%
a["Date"].value_counts()
# Out:
# 2020-11-06    37
# 2021-02-06    36
# 2021-01-28    36
# 2020-07-15    36
# 2020-12-20    36
# 2021-02-15    36
# 2021-01-02    36
# 2021-02-28    36
# 2021-01-15    36
# 2020-10-06    36
# 2020-06-27    36
# 2020-12-15    36
# 2020-12-07    36
# 2020-05-27    36
# 2020-12-28    36
# 2021-02-23    36
# 2020-06-22    36
# 2021-01-23    36
# 2021-02-05    36
# 2020-07-18    36
# 2020-12-23    36
# 2021-02-18    36
# 2021-02-02    36
# 2020-05-06    36
# 2020-06-17    36
# 2020-08-07    36
# 2020-03-07    36
# 2021-01-17    36
# 2020-06-29    36
# 2021-01-30    36
#               ..
# 2020-03-03     4
# 2020-02-03     3
# 2020-02-16     1
# 2020-02-25     1
# 2020-02-27     1
# 2020-02-14     1
# 2020-06-02     1
# 2020-04-02     1
# 2020-02-22     1
# 2020-02-18     1
# 2020-02-20     1
# 2020-03-02     1
# 2020-02-19     1
# 2020-10-02     1
# 2020-02-24     1
# 2020-05-02     1
# 2020-02-02     1
# 2020-09-02     1
# 2020-02-13     1
# 2020-02-26     1
# 2020-08-02     1
# ...

# %%
a
# Out:
#          Sno       Date      Time                      State/UnionTerritory  \
# 3          4 2020-02-02  06:00 PM                                    Kerala
# 4          5 2020-03-02  06:00 PM                                    Kerala
# 5          6 2020-04-02  06:00 PM                                    Kerala
# 6          7 2020-05-02  06:00 PM                                    Kerala
# 7          8 2020-06-02  06:00 PM                                    Kerala
# 8          9 2020-07-02  06:00 PM                                    Kerala
# 9         10 2020-08-02  06:00 PM                                    Kerala
# 10        11 2020-09-02  06:00 PM                                    Kerala
# 11        12 2020-10-02  06:00 PM                                    Kerala
# 12        13 2020-11-02  06:00 PM                                    Kerala
# 13        14 2020-12-02  06:00 PM                                    Kerala
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11642 entries, 3 to 17785
# Data columns (total 9 columns):
# Sno                         11642 non-null int64
# Date                        11642 non-null datetime64[ns]
# Time                        11642 non-null object
# State/UnionTerritory        11642 non-null object
# ConfirmedIndianNational     11642 non-null object
# ConfirmedForeignNational    11642 non-null object
# Cured                       11642 non-null int64
# Deaths                      11642 non-null int64
# Confirmed                   11642 non-null int64
# dtypes: datetime64[ns](1), int64(4), object(4)
# memory usage: 909.5+ KB

# %% [markdown]
# # Formate 2(between)

# %%
dataset=dataset.loc[dataset["Date"].between("2020-02-01","2021-03-01")]
dataset
# Out:
#          Sno       Date      Time                      State/UnionTerritory  \
# 3          4 2020-02-02  06:00 PM                                    Kerala
# 4          5 2020-03-02  06:00 PM                                    Kerala
# 5          6 2020-04-02  06:00 PM                                    Kerala
# 6          7 2020-05-02  06:00 PM                                    Kerala
# 7          8 2020-06-02  06:00 PM                                    Kerala
# 8          9 2020-07-02  06:00 PM                                    Kerala
# 9         10 2020-08-02  06:00 PM                                    Kerala
# 10        11 2020-09-02  06:00 PM                                    Kerala
# 11        12 2020-10-02  06:00 PM                                    Kerala
# 12        13 2020-11-02  06:00 PM                                    Kerala
# 13        14 2020-12-02  06:00 PM                                    Kerala
# ...

# %% [markdown]
# # Formate 3(isin)

# %%
b=dataset[dataset["Date"].isin(pd.date_range(start='2020-02-01', end='2021-03-01'))]
b
# Out:
#          Sno       Date      Time                      State/UnionTerritory  \
# 3          4 2020-02-02  06:00 PM                                    Kerala
# 4          5 2020-03-02  06:00 PM                                    Kerala
# 5          6 2020-04-02  06:00 PM                                    Kerala
# 6          7 2020-05-02  06:00 PM                                    Kerala
# 7          8 2020-06-02  06:00 PM                                    Kerala
# 8          9 2020-07-02  06:00 PM                                    Kerala
# 9         10 2020-08-02  06:00 PM                                    Kerala
# 10        11 2020-09-02  06:00 PM                                    Kerala
# 11        12 2020-10-02  06:00 PM                                    Kerala
# 12        13 2020-11-02  06:00 PM                                    Kerala
# 13        14 2020-12-02  06:00 PM                                    Kerala
# ...

# %% [markdown]
# # pivot_Table

# %%
dataset=pd.read_csv("D:\Datasets\garments_worker_productivity.csv")

# %%
dataset
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# 5      1/1/2015  Quarter1      sweing   Thursday     7                   0.80
# 6      1/1/2015  Quarter1  finishing    Thursday     2                   0.75
# 7      1/1/2015  Quarter1      sweing   Thursday     3                   0.75
# 8      1/1/2015  Quarter1      sweing   Thursday     2                   0.75
# 9      1/1/2015  Quarter1      sweing   Thursday     1                   0.75
# 10     1/1/2015  Quarter1      sweing   Thursday     9                   0.70
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 15 columns):
# date                     1197 non-null object
# quarter                  1197 non-null object
# department               1197 non-null object
# day                      1197 non-null object
# team                     1197 non-null int64
# targeted_productivity    1197 non-null float64
# smv                      1197 non-null float64
# wip                      691 non-null float64
# over_time                1197 non-null int64
# incentive                1197 non-null int64
# idle_time                1197 non-null float64
# idle_men                 1197 non-null int64
# no_of_style_change       1197 non-null int64
# no_of_workers            1197 non-null float64
# actual_productivity      1197 non-null float64
# dtypes: float64(6), int64(5), object(4)
# memory usage: 140.4+ KB

# %%
dataset.describe()
# Out:
#               team  targeted_productivity          smv           wip  \
# count  1197.000000            1197.000000  1197.000000    691.000000
# mean      6.426901               0.729632    15.062172   1190.465991
# std       3.463963               0.097891    10.943219   1837.455001
# min       1.000000               0.070000     2.900000      7.000000
# 25%       3.000000               0.700000     3.940000    774.500000
# 50%       6.000000               0.750000    15.260000   1039.000000
# 75%       9.000000               0.800000    24.260000   1252.500000
# max      12.000000               0.800000    54.560000  23122.000000
#
#           over_time    incentive    idle_time     idle_men  \
# count   1197.000000  1197.000000  1197.000000  1197.000000
# mean    4567.460317    38.210526     0.730159     0.369256
# std     3348.823563   160.182643    12.709757     3.268987
# min        0.000000     0.000000     0.000000     0.000000
# ...

# %%
dataset.isnull().any()
# Out:
# date                     False
# quarter                  False
# department               False
# day                      False
# team                     False
# targeted_productivity    False
# smv                      False
# wip                       True
# over_time                False
# incentive                False
# idle_time                False
# idle_men                 False
# no_of_style_change       False
# no_of_workers            False
# actual_productivity      False
# dtype: bool

# %%
dataset.isnull().sum()
# Out:
# date                       0
# quarter                    0
# department                 0
# day                        0
# team                       0
# targeted_productivity      0
# smv                        0
# wip                      506
# over_time                  0
# incentive                  0
# idle_time                  0
# idle_men                   0
# no_of_style_change         0
# no_of_workers              0
# actual_productivity        0
# dtype: int64

# %%
dataset["department"].unique()
# Out:
# array(['sweing', 'finishing ', 'finishing'], dtype=object)

# %%
x=pd.pivot_table(dataset,index="department")

# %%
x
# Out:
#             actual_productivity  idle_men  idle_time  incentive  \
# department
# finishing              0.722876  0.000000   0.000000  60.240964
# finishing              0.782089  0.000000   0.000000   0.000000
# sweing                 0.722013  0.639653   1.264834  44.483357
#
#             no_of_style_change  no_of_workers    over_time        smv  \
# department
# finishing             0.000000      10.397590  1792.530120   3.979719
# finishing             0.000000      10.112840  2037.898833   3.797237
# sweing                0.260492      52.445731  6508.205499  23.245412
#
#             targeted_productivity      team          wip
# department
# finishing                0.731325  6.337349          NaN
# finishing                0.743191  6.260700          NaN
# sweing                   0.723980  6.520984  1190.465991

# %%
dataset["day"].unique()
# Out:
# array(['Thursday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday'], dtype=object)

# %%
x=pd.pivot_table(dataset,index=["department","day"])
x
# Out:
#                       actual_productivity  idle_men  idle_time   incentive  \
# department day
# finishing  Monday                0.712026  0.000000   0.000000  375.000000
#            Saturday              0.690843  0.000000   0.000000    0.000000
#            Sunday                0.725270  0.000000   0.000000    0.000000
#            Thursday              0.728957  0.000000   0.000000    0.000000
#            Tuesday               0.718827  0.000000   0.000000    0.000000
#            Wednesday             0.747741  0.000000   0.000000    0.000000
# finishing  Monday                0.787850  0.000000   0.000000    0.000000
#            Saturday              0.826654  0.000000   0.000000    0.000000
#            Sunday                0.771552  0.000000   0.000000    0.000000
#            Thursday              0.750122  0.000000   0.000000    0.000000
#            Tuesday               0.811395  0.000000   0.000000    0.000000
# ...

# %%
dataset["quarter"].unique()
# Out:
# array(['Quarter1', 'Quarter2', 'Quarter3', 'Quarter4', 'Quarter5'], dtype=object)

# %%
x=pd.pivot_table(dataset,index=["department","day","quarter"])
x
# Out:
#                                actual_productivity  idle_men  idle_time  \
# department day       quarter
# finishing  Monday    Quarter1             0.698903  0.000000   0.000000
#                      Quarter2             0.747692  0.000000   0.000000
#                      Quarter3             0.728522  0.000000   0.000000
#                      Quarter4             0.641020  0.000000   0.000000
#            Saturday  Quarter1             0.750265  0.000000   0.000000
#                      Quarter2             0.696613  0.000000   0.000000
#                      Quarter4             0.580717  0.000000   0.000000
#            Sunday    Quarter1             0.614857  0.000000   0.000000
#                      Quarter2             0.773119  0.000000   0.000000
#                      Quarter3             0.759699  0.000000   0.000000
#                      Quarter4             0.697114  0.000000   0.000000
#            Thursday  Quarter1             0.824389  0.000000   0.000000
# ...

# %%
dataset=pd.read_csv("D:\Datasets\garments_worker_productivity.csv")
dataset
# Out:
#            date   quarter  department        day  team  targeted_productivity  \
# 0      1/1/2015  Quarter1      sweing   Thursday     8                   0.80
# 1      1/1/2015  Quarter1  finishing    Thursday     1                   0.75
# 2      1/1/2015  Quarter1      sweing   Thursday    11                   0.80
# 3      1/1/2015  Quarter1      sweing   Thursday    12                   0.80
# 4      1/1/2015  Quarter1      sweing   Thursday     6                   0.80
# 5      1/1/2015  Quarter1      sweing   Thursday     7                   0.80
# 6      1/1/2015  Quarter1  finishing    Thursday     2                   0.75
# 7      1/1/2015  Quarter1      sweing   Thursday     3                   0.75
# 8      1/1/2015  Quarter1      sweing   Thursday     2                   0.75
# 9      1/1/2015  Quarter1      sweing   Thursday     1                   0.75
# 10     1/1/2015  Quarter1      sweing   Thursday     9                   0.70
# ...

# %%
y= pd.pivot_table(dataset,values="targeted_productivity",columns=["day"],index=["department"])
y
# Out:
# day           Monday  Saturday    Sunday  Thursday   Tuesday  Wednesday
# department
# finishing   0.737500  0.732813  0.730233  0.734615  0.718605   0.734615
# finishing   0.741860  0.751961  0.750000  0.733333  0.746250   0.732432
# sweing      0.721983  0.725000  0.735345  0.711610  0.724576   0.725630

# %%
q=pd.pivot_table(dataset,columns=["date"],index=["day"],aggfunc=[sum,np.mean,np.std])
q
# Out:
#                           sum                                              \
#           actual_productivity
# date                 1/1/2015  1/10/2015  1/11/2015  1/12/2015  1/13/2015
# day
# Monday                    NaN        NaN        NaN  17.369459        NaN
# Saturday                  NaN  16.968712        NaN        NaN        NaN
# Sunday                    NaN        NaN  17.228024        NaN        NaN
# Thursday            13.655501        NaN        NaN        NaN        NaN
# Tuesday                   NaN        NaN        NaN        NaN  16.622455
# Wednesday                 NaN        NaN        NaN        NaN        NaN
#
#                                                                     ...      \
#                                                                     ...
# date       1/14/2015  1/15/2015  1/17/2015  1/18/2015  1/19/2015    ...
# day                                                                 ...
# ...
