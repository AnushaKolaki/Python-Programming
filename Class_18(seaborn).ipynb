# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset=pd.read_csv(r"D:\Datasets\tips.csv")
dataset
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(x="total_bill",y="tip",data=dataset)

# %%
sns.relplot(x="total_bill",y="tip",data=dataset,marker="*")

# %%
sns.relplot(x="total_bill",y="tip",data=dataset,marker="^")

# %%
sns.relplot(x="total_bill",y="tip",data=dataset,marker="*",hue="sex")

# %%
sns.relplot(x="total_bill",y="tip",data=dataset,marker="*",hue="sex",style="smoker")

# %%
sns.relplot(x="total_bill",y="tip",data=dataset,marker="*",hue="sex",style="smoker",size="day")

# %%
sns.relplot(x="total_bill",y="day",data=dataset,marker="*",hue="sex",style="smoker")
plt.xlabel("Day")
plt.ylabel("total_bill")
# Out:
# Text(31.753984375, 0.5, 'total_bill')

# %%
sns.relplot(x="day",y="smoker",data=dataset,marker="*",hue="sex")

# %%
sns.relplot(x="tip",y="day",data=dataset,marker="*",hue="sex")

# %%
sns.relplot(data=dataset,x="total_bill",y="tip",hue="sex")

# %%
sns.relplot(data=dataset,x="total_bill",y="tip",style="day")

# %%
sns.relplot(data=dataset,x="total_bill",y="tip",hue="day")

# %%
sns.relplot(data=dataset,x="total_bill",y="tip",size="day")

# %%
sns.relplot(data=dataset,x="total_bill",y="tip",hue="day",style="time",size="smoker")

# %%
sns.catplot(x="tip",y="day",data=dataset,hue="sex")

# %%
sns.catplot(x="tip",y="smoker",data=dataset,hue="sex")

# %%
sns.catplot(x="total_bill",y="day",data=dataset,marker="^",hue="sex")

# %%
sns.catplot(x="total_bill",y="sex",data=dataset,hue="time")
