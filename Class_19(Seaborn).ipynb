# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
a=sns.load_dataset("tips")
a
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set(style="whitegrid")

# %%
sns.relplot(data=a,x="total_bill",y="sex")

# %%
sns.relplot(data=a,x="total_bill",y="tip")

# %%
sns.relplot(data=a,x="total_bill",y="tip",color="r",style="sex")

# %%
sns.relplot(data=a,x="total_bill",y="tip",style="day")

# %%
sns.set(style="darkgrid")

# %%
sns.relplot(data=a,x="total_bill",y="tip",size="day")

# %%
d=a.loc[(a["sex"]=="Female") | (a["smoker"]=="yes"),["sex","smoker"]]
d
# Out:
#         sex smoker
# 0    Female     No
# 4    Female     No
# 11   Female     No
# 14   Female     No
# 16   Female     No
# ..      ...    ...
# 226  Female    Yes
# 229  Female    Yes
# 238  Female     No
# 240  Female    Yes
# 243  Female     No
#
# [87 rows x 2 columns]

# %%
sns.countplot(data=d,x="sex")
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.relplot(data=a,x="total_bill",y="tip",col="day")

# %%
sns.relplot(data=a,x="total_bill",y="tip",col="day",size="sex")

# %%
sns.relplot(data=a,x="total_bill",y="tip",col="day",size="sex",style="day")

# %%
sns.relplot(data=a,x="total_bill",y="tip",col="sex",size="smoker",style="day",hue="time")
